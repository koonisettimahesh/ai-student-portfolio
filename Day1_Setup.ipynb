# %% [markdown]
# <a href="https://colab.research.google.com/github/koonisettimahesh/ai-student-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the progression from basic data understanding to cutting-edge AI research:
#
# *   **Layer 1: Data Fluency & AI Application:** The base layer focuses on understanding data principles, ethics, and effectively using existing AI tools and platforms.
# *   **Layer 2: AI Fundamentals & Understanding:** Progresses to grasping core machine learning concepts, algorithms, and how AI models work.
# *   **Layer 3: AI Development & Engineering:** Involves building, training, deploying, and maintaining custom AI models and systems.
# *   **Layer 4: AI Research & Innovation:** The apex, focused on developing new AI algorithms, advancing the field, and exploring theoretical frontiers.

# %%
pip install -q google-genai
